# %% [markdown]
# # Watch Me Code 2: Reading HTML tables from Websites

# %%
import pandas as pd

# %%
# HTTP Error - need to set a user agent
tables = pd.read_html("https://ist256.github.io")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # HTTP Error - need to set a user agent
# ----> 2 tables = pd.read_html("https://ist256.github.io")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/html.py:1245, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1229 if isinstance(io, str) and not any(
#    1230     [
#    1231         is_file_like(io),
#    (...)
#    1235     ]
#    1236 ):
#    1237     warnings.warn(
#    1238         "Passing literal html to 'read_html' is deprecated and "
#    1239         "will be removed in a future version. To read from a "
#    (...)
#    1242         stacklevel=find_stack_level(),
#    1243     )
# -> 1245 return _parse(
#    1246     flavor=flavor,
#    1247     io=io,
#    1248     match=match,
#    1249     header=header,
#    1250     index_col=index_col,
#    1251     skiprows=skiprows,
#    1252     parse_dates=parse_dates,
#    1253     thousands=thousands,
#    1254     attrs=attrs,
#    1255     encoding=encoding,
#    1256     decimal=decimal,
#    1257     converters=converters,
#    1258     na_values=na_values,
#    1259     keep_default_na=keep_default_na,
#    1260     displayed_only=displayed_only,
#    1261     extract_links=extract_links,
#    1262     dtype_backend=dtype_backend,
#    1263     storage_options=storage_options,
#    1264 )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/html.py:988, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     977 p = parser(
#     978     io,
#     979     compiled_match,
#    (...)
#     984     storage_options,
#     985 )
#     987 try:
# --> 988     tables = p.parse_tables()
#     989 except ValueError as caught:
#     990     # if `io` is an io-like object, check if it's seekable
#     991     # and try to rewind it before trying the next parser
#     992     if hasattr(io, "seekable") and io.seekable():
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/html.py:248, in _HtmlFrameParser.parse_tables(self)
#     240 def parse_tables(self):
#     241     """
#     242     Parse and return all tables from the DOM.
#     243
#    (...)
#     246     list of parsed (header, body, footer) tuples from tables.
#     247     """
# --> 248     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     249     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/html.py:811, in _LxmlFrameParser._build_doc(self)
#     809             pass
#     810     else:
# --> 811         raise e
#     812 else:
#     813     if not hasattr(r, "text_content"):
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/html.py:790, in _LxmlFrameParser._build_doc(self)
#     788 try:
#     789     if is_url(self.io):
# --> 790         with get_handle(
#     791             self.io, "r", storage_options=self.storage_options
#     792         ) as f:
#     793             r = parse(f.handle, parser=parser)
#     794     else:
#     795         # try to parse the input in the simplest way
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/common.py:718, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     715     codecs.lookup_error(errors)
#     717 # open URLs
# --> 718 ioargs = _get_filepath_or_buffer(
#     719     path_or_buf,
#     720     encoding=encoding,
#     721     compression=compression,
#     722     mode=mode,
#     723     storage_options=storage_options,
#     724 )
#     726 handle = ioargs.filepath_or_buffer
#     727 handles: list[BaseBuffer]
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/common.py:372, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     370 # assuming storage_options is to be interpreted as headers
#     371 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 372 with urlopen(req_info) as req:
#     373     content_encoding = req.headers.get("Content-Encoding", None)
#     374     if content_encoding == "gzip":
#     375         # Override compression based on Content-Encoding header
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/common.py:274, in urlopen(*args, **kwargs)
#     268 """
#     269 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     270 the stdlib.
#     271 """
#     272 import urllib.request
# --> 274 return urllib.request.urlopen(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /opt/conda/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /opt/conda/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /opt/conda/lib/python3.11/urllib/request.py:557, in OpenerDirector.error(self, proto, *args)
#     555     http_err = 0
#     556 args = (dict, proto, meth_name) + args
# --> 557 result = self._call_chain(*args)
#     558 if result:
#     559     return result
#
# File /opt/conda/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /opt/conda/lib/python3.11/urllib/request.py:749, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     746 fp.read()
#     747 fp.close()
# --> 749 return self.parent.open(new, timeout=req.timeout)
#
# File /opt/conda/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /opt/conda/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /opt/conda/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File /opt/conda/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /opt/conda/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
headers = {"User-Agent": "Mozilla/5.0"}
tables = pd.read_html("https://ist256.github.io", storage_options=headers)

# %%
len(tables)
# Out:
# 2

# %%
tables[1]
# Out:
#      Date Due  Time Due Gradebook  Points        Where  \
# 0   1/23/2024  11:59 PM       L01       3   Jupyterhub
# 1   1/24/2024  11:59 PM       S01       3   Jupyterhub
# 2   1/26/2024  11:59 PM       H01       3   Jupyterhub
# 3   1/30/2024  11:59 PM       L02       3   Jupyterhub
# 4   1/31/2024  11:59 PM       S02       3   Jupyterhub
# 5    2/2/2024  11:59 PM       H02       3   Jupyterhub
# 6    2/6/2024  11:59 PM       L03       3   Jupyterhub
# 7    2/7/2024  11:59 PM       S03       3   Jupyterhub
# 8    2/9/2024  11:59 PM       H03       3   Jupyterhub
# 9   2/13/2024  11:59 PM       L04       3   Jupyterhub
# 10  2/14/2024  11:59 PM       S04       3   Jupyterhub
# 11  2/14/2024  11:59 PM        E1      23  Small Group
# 12  2/16/2024  11:59 PM       H04       3   Jupyterhub
# 13  2/20/2024  11:59 PM       L05       3   Jupyterhub
# 14  2/21/2024  11:59 PM       S05       3   Jupyterhub
# 15  2/23/2024  11:59 PM       H05       3   Jupyterhub
# 16  2/27/2024  11:59 PM       L06       3   Jupyterhub
# 17  2/28/2024  11:59 PM       S06       3   Jupyterhub
# 18   3/1/2024  11:59 PM       H06       3   Jupyterhub
# 19   3/5/2024  11:59 PM       L07       3   Jupyterhub
# 20   3/6/2024  11:59 PM       S07       3   Jupyterhub
# 21   3/6/2024  11:59 PM        E2      23  Small Group
# 22   3/8/2024  11:59 PM       H07       3   Jupyterhub
# 23  3/19/2024  11:59 PM       L08       3   Jupyterhub
# 24  3/20/2024  11:59 PM       S08       3   Jupyterhub
# 25  3/22/2024  11:59 PM       H08       3   Jupyterhub
# 26  3/26/2024  11:59 PM       L09       3   Jupyterhub
# 27  3/27/2024  11:59 PM       S09       3   Jupyterhub
# 28  3/29/2024  11:59 PM       H09       3   Jupyterhub
# 29   4/2/2024  11:59 PM       L10       3   Jupyterhub
# 30   4/3/2024  11:59 PM       S10       3   Jupyterhub
# 31   4/3/2024  11:59 PM        E3      22  Small Group
# 32   4/5/2024  11:59 PM       H10       3   Jupyterhub
# 33   4/9/2024  11:59 PM       L11       3   Jupyterhub
# 34  4/10/2024  11:59 PM       S11       3   Jupyterhub
# 35  4/12/2024  11:59 PM       H11       3   Jupyterhub
# 36  4/12/2024  11:59 PM        P1       0   Jupyterhub
# 37  4/16/2024  11:59 PM       L12       3   Jupyterhub
# 38  4/17/2024  11:59 PM       S12       3   Jupyterhub
# 39  4/19/2024  11:59 PM       H12       3   Jupyterhub
# 40  4/23/2024  11:59 PM       L13       3   Jupyterhub
# 41  4/24/2024  11:59 PM       S13       3   Jupyterhub
# 42  4/24/2024  11:59 PM        E4      22  Small Group
# 43  4/26/2024  11:59 PM       H13       3   Jupyterhub
# 44  4/29/2024  11:59 PM        P2       0   Jupyterhub
# 45   5/7/2024  11:59 PM        P3       0   Jupyterhub
# 46   5/7/2024  11:59 PM        P4      49   Jupyterhub
#
#                                        What is Due?
# 0                          01-Intro/LAB-Intro.ipynb
# 1                   01-Intro/SmallGroup-Intro.ipynb
# 2                           01-Intro/HW-Intro.ipynb
# 3                  02-Variables/LAB-Variables.ipynb
# 4           02-Variables/SmallGroup-Variables.ipynb
# 5                   02-Variables/HW-Variables.ipynb
# 6            03-Conditionals/LAB-Conditionals.ipynb
# 7     03-Conditionals/SmallGroup-Conditionals.ipynb
# 8             03-Conditionals/HW-Conditionals.ipynb
# 9                04-Iterations/LAB-Iterations.ipynb
# 10        04-Iterations/SmallGroup-Iterations.ipynb
# 11                E1: Exam 1 (Focus on Lessons 1-3)
# 12                04-Iterations/HW-Iterations.ipynb
# 13                 05-Functions/LAB-Functions.ipynb
# 14          05-Functions/SmallGroup-Functions.ipynb
# 15                  05-Functions/HW-Functions.ipynb
# 16                     06-Strings/LAB-Strings.ipynb
# 17              06-Strings/SmallGroup-Strings.ipynb
# 18                      06-Strings/HW-Strings.ipynb
# 19                         07-Files/LAB-Files.ipynb
# 20                  07-Files/SmallGroup-Files.ipynb
# 21                E2: Exam 2 (Focus on Lessons 4-6)
# 22                          07-Files/HW-Files.ipynb
# 23                         08-Lists/LAB-Lists.ipynb
# 24                  08-Lists/SmallGroup-Lists.ipynb
# 25                          08-Lists/HW-Lists.ipynb
# 26           09-Dictionaries/LAB-Dictionaries.ipynb
# 27    09-Dictionaries/SmallGroup-Dictionaries.ipynb
# 28            09-Dictionaries/HW-Dictionaries.ipynb
# 29                    10-Pandas-I/LAB-PandasI.ipynb
# 30             10-Pandas-I/SmallGroup-PandasI.ipynb
# 31                Q3: Exam 3 (Focus on Lessons 7-9)
# 32                     10-Pandas-I/HW-PandasI.ipynb
# 33                  11-Pandas-II/LAB-PandasII.ipynb
# 34           11-Pandas-II/SmallGroup-PandasII.ipynb
# 35                   11-Pandas-II/HW-PandasII.ipynb
# 36                                 project/P1.ipynb
# 37         12-Visualization/LAB-Visualization.ipynb
# 38  12-Visualization/SmallGroup-Visualization.ipynb
# 39          12-Visualization/HW-Visualization.ipynb
# 40                     13-WebAPIs/LAB-Webapis.ipynb
# 41              13-WebAPIs/SmallGroup-Webapis.ipynb
# 42              E4: Exam 4 (Focus on Lessons 10-12)
# 43                      13-WebAPIs/HW-Webapis.ipynb
# 44                                 project/P2.ipynb
# 45                                 project/P3.ipynb
# 46                                 project/P4.ipynb

# %%
headers = {"User-Agent": "Mozilla/5.0"}
tables = pd.read_html("https://www.baseball-reference.com/leagues/MLB-standings.shtml", storage_options=headers)
len(tables)
# Out:
# 6

# %%
from IPython.display import display
for index in range(len(tables)):
    print("INDEX:", index)
    display(tables[index])
# Out:
# INDEX: 0
#                   Tm  W  L   W-L%   GB
# 0   New York Yankees  8  2  0.800   --
# 1     Boston Red Sox  7  3  0.700  1.0
# 2  Baltimore Orioles  5  4  0.556  2.5
# 3     Tampa Bay Rays  5  5  0.500  3.0
# 4  Toronto Blue Jays  4  6  0.400  4.0
# INDEX: 1
#                     Tm  W  L   W-L%   GB
# 0  Cleveland Guardians  7  2  0.778   --
# 1       Detroit Tigers  6  3  0.667  1.0
# 2   Kansas City Royals  6  4  0.600  1.5
# 3      Minnesota Twins  3  4  0.429  3.0
# 4    Chicago White Sox  1  8  0.111  6.0
# INDEX: 2
#                    Tm  W  L   W-L%   GB
# 0       Texas Rangers  6  3  0.667   --
# 1  Los Angeles Angels  5  4  0.556  1.0
# 2    Seattle Mariners  4  6  0.400  2.5
# 3      Houston Astros  3  7  0.300  3.5
# 4   Oakland Athletics  3  7  0.300  3.5
# INDEX: 3
#                       Tm  W  L   W-L%   GB
# 0         Atlanta Braves  6  2  0.750   --
# 1  Philadelphia Phillies  4  5  0.444  2.5
# 2          New York Mets  3  6  0.333  3.5
# 3   Washington Nationals  3  6  0.333  3.5
# 4          Miami Marlins  1  9  0.100  6.0
# INDEX: 4
#                     Tm  W  L   W-L%   GB
# 0   Pittsburgh Pirates  8  2  0.800   --
# 1    Milwaukee Brewers  6  2  0.750  1.0
# 2         Chicago Cubs  6  3  0.667  1.5
# 3      Cincinnati Reds  5  4  0.556  2.5
# 4  St. Louis Cardinals  5  5  0.500  3.0
# INDEX: 5
#                      Tm  W  L   W-L%   GB
# 0   Los Angeles Dodgers  8  4  0.667   --
# 1      San Diego Padres  5  7  0.417  3.0
# 2  Arizona Diamondbacks  4  6  0.400  3.0
# 3  San Francisco Giants  4  6  0.400  3.0
# 4      Colorado Rockies  2  8  0.200  5.0

# %%
tables[0]['League'] = 'AL'
tables[0]['Division'] = 'East'

# %%
teams_df = pd.concat(tables, ignore_index=True)

# %%
teams_df
# Out:
#                        Tm  W  L   W-L%   GB League Division
# 0        New York Yankees  8  2  0.800   --     AL     East
# 1          Boston Red Sox  7  3  0.700  1.0     AL     East
# 2       Baltimore Orioles  5  4  0.556  2.5     AL     East
# 3          Tampa Bay Rays  5  5  0.500  3.0     AL     East
# 4       Toronto Blue Jays  4  6  0.400  4.0     AL     East
# 5     Cleveland Guardians  7  2  0.778   --    NaN      NaN
# 6          Detroit Tigers  6  3  0.667  1.0    NaN      NaN
# 7      Kansas City Royals  6  4  0.600  1.5    NaN      NaN
# 8         Minnesota Twins  3  4  0.429  3.0    NaN      NaN
# 9       Chicago White Sox  1  8  0.111  6.0    NaN      NaN
# 10          Texas Rangers  6  3  0.667   --    NaN      NaN
# 11     Los Angeles Angels  5  4  0.556  1.0    NaN      NaN
# 12       Seattle Mariners  4  6  0.400  2.5    NaN      NaN
# 13         Houston Astros  3  7  0.300  3.5    NaN      NaN
# 14      Oakland Athletics  3  7  0.300  3.5    NaN      NaN
# 15         Atlanta Braves  6  2  0.750   --    NaN      NaN
# 16  Philadelphia Phillies  4  5  0.444  2.5    NaN      NaN
# 17          New York Mets  3  6  0.333  3.5    NaN      NaN
# 18   Washington Nationals  3  6  0.333  3.5    NaN      NaN
# 19          Miami Marlins  1  9  0.100  6.0    NaN      NaN
# 20     Pittsburgh Pirates  8  2  0.800   --    NaN      NaN
# 21      Milwaukee Brewers  6  2  0.750  1.0    NaN      NaN
# 22           Chicago Cubs  6  3  0.667  1.5    NaN      NaN
# 23        Cincinnati Reds  5  4  0.556  2.5    NaN      NaN
# 24    St. Louis Cardinals  5  5  0.500  3.0    NaN      NaN
# 25    Los Angeles Dodgers  8  4  0.667   --    NaN      NaN
# 26       San Diego Padres  5  7  0.417  3.0    NaN      NaN
# 27   Arizona Diamondbacks  4  6  0.400  3.0    NaN      NaN
# 28   San Francisco Giants  4  6  0.400  3.0    NaN      NaN
# 29       Colorado Rockies  2  8  0.200  5.0    NaN      NaN

# %%
teams_df.loc[25, "Tm"]
# Out:
# 'Los Angeles Dodgers'

# %%
# Everone who has more than 5 wins
teams_df[ teams_df['W'] > 5 ]
# Out:
#                      Tm  W  L   W-L%   GB League Division
# 0      New York Yankees  8  2  0.800   --     AL     East
# 1        Boston Red Sox  7  3  0.700  1.0     AL     East
# 5   Cleveland Guardians  7  2  0.778   --    NaN      NaN
# 6        Detroit Tigers  6  3  0.667  1.0    NaN      NaN
# 7    Kansas City Royals  6  4  0.600  1.5    NaN      NaN
# 10        Texas Rangers  6  3  0.667   --    NaN      NaN
# 15       Atlanta Braves  6  2  0.750   --    NaN      NaN
# 20   Pittsburgh Pirates  8  2  0.800   --    NaN      NaN
# 21    Milwaukee Brewers  6  2  0.750  1.0    NaN      NaN
# 22         Chicago Cubs  6  3  0.667  1.5    NaN      NaN
# 25  Los Angeles Dodgers  8  4  0.667   --    NaN      NaN
