# %% [markdown]
# # End-To-End Example: Plotting and Mapping Potholes
#
# Let's do a data analysis of Syracuse Potholes based on data from the civic hackathon https://cityofsyracuse.github.io/RoadsChallenge/
#
# We will plot data and display pothole locations on a map!

# %%
import folium
import pandas as pd

# %% [markdown]
# First we need to find the latitude and longitude of Syracuse, then estimate the appropriate zoom level...

# %%
SYR = (43.0481, -76.1474)
map = folium.Map(location=SYR, zoom_start=14)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0003cdfa3bffbd5bf19f10a5a0a203ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0003cdfa3bffbd5bf19f10a5a0a203ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0003cdfa3bffbd5bf19f10a5a0a203ef = L.map(
#                 &quot;map_0003cdfa3bffbd5bf19f10a5a0a203ef&quot;,
#                 {
#                     center: [43.0481, -76.1474],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09a9373bcd063d6767efe3907acaef72 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_09a9373bcd063d6767efe3907acaef72.addTo(map_0003cdfa3bffbd5bf19f10a5a0a203ef);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We get the data from the RoadsChallange github account

# %%
data = pd.read_csv('https://cityofsyracuse.github.io/RoadsChallenge/data/potholes.csv')
data.sample(5)
# Out:
#      StreetNumber StreetName StreetNamePostType Directional  \
# 4368          154   ST LOUIS                AVE
# 2165          951     SOUTH                 AVE
# 1152          115   PARKWAY                  DR
# 485           328   MERRITT                 AVE
# 2957         1002   MIDLAND                 AVE
#
#                         strLocation           dtTime  STREET_ID VehicleName  \
# 4368  154 ST LOUIS AVE & BARNES AVE  5/24/2016 10:38   12571922         DP1
# 2165                  951 SOUTH AVE  4/30/2016 11:44   13002135         DP2
# 1152     115 PARKWAY DR & TEMPLE PL  4/21/2016 10:54   12572060         DP1
# 485     328 MERRITT AVE & HOPPER RD  4/16/2016 12:59   12571720         DP2
# 2957  1002 MIDLAND AVE & KENNEDY ST  5/11/2016 11:03   12573203         DP2
#
#        Latitude  Longitude
# 4368 -76.159961  43.008893
# 2165 -76.159352  43.026842
# 1152 -76.159859  43.024401
# 485  -76.159558  42.998903
# 2957 -76.152795  43.029187

# %% [markdown]
# **Note:** The `Latitude` and `Longitude` Series named are reversed in the dataset.
#
# Now we take the latitude and longitude of each pothole and show them on a map using circle markers

# %%
# NOTE: to_dict('records') converts a pandas dataframe back to a list of dict!
SYR = (43.0481, -76.1474)
map = folium.Map(location=SYR, zoom_start=14)
# get 500 random samples to plot.
subset = data.sample(500)
for row in subset.to_records():
    coords = (row['Longitude'],row['Latitude'])
    loc = str(row['strLocation']) + ' ' + str(row['dtTime'])
    marker = folium.Marker(location=coords, popup=loc)
    marker.add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1cd3feafe312d8a3bbf505e6b569033 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1cd3feafe312d8a3bbf505e6b569033&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1cd3feafe312d8a3bbf505e6b569033 = L.map(
#                 &quot;map_c1cd3feafe312d8a3bbf505e6b569033&quot;,
#                 {
#                     center: [43.0481, -76.1474],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8f98901c1f83e0278c2a42f2f89c065 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e8f98901c1f83e0278c2a42f2f89c065.addTo(map_c1cd3feafe312d8a3bbf505e6b569033);
#
#
#             var marker_dbb8f88b766793c3a73d1a7edf52c298 = L.marker(
#                 [43.0196812051, -76.1555782423],
#                 {}
#             ).addTo(map_c1cd3feafe312d8a3bbf505e6b569033);
#
#
#         var popup_668e5f65f68df09883ca20deca93a7ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_324dfe7a78d0b8114aaad65361d48910 = $(`&lt;div id=&quot;html_324dfe7a78d0b8114aaad65361d48910&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;400 HUNT AVE &amp; MARGUERITE AVE 5/23/2016 15:06&lt;/div&gt;`)[0];
#                 popup_668e5f65f68df09883ca20deca93a7ff.setContent(html_324dfe7a78d0b8114aaad65361d48910);
#
#
#
#         marker_dbb8f88b766793c3a73d1a7edf52c298.bindPopup(popup_668e5f65f68df09883ca20deca93a7ff)
#         ;
#
#
#
#
#             var marker_7395af74da8cf05fb1a26c20991b8de4 = L.marker(
#                 [42.997825896, -76.1500471354],
#                 {}
#             ).addTo(map_c1cd3feafe312d8a3bbf505e6b569033);
#
#
#         var popup_0ad8f39a174ae202415eba12cc736fa1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37a54769891a978c64da309e594d5ba3 = $(`&lt;div id=&quot;html_37a54769891a978c64da309e594d5ba3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;125 CHAFFEE AVE E 4/18/2016 13:08&lt;/div&gt;`)[0];
#                 popup_0ad8f39a174ae202415eba12cc736fa1.setContent(html_37a54769891a978c64da309e594d5ba3);
#
#
#
#         marker_7395af74da8cf05fb1a26c20991b8de4.bindPopup(popup_0ad8f39a174ae202415eba12cc736fa1)
#         ;
#
#
#
#
#             var marker_b4c0ff8e5504d744fc258fd9b2f212cf = L.marker(
#                 [43.0089134017, -76.1599607453],
#                 {}
#             ).addTo(map_c1cd3feafe312d8a3bbf505e6b569033);
#
#
#         var popup_18253435e8c26c38c9e7ca748bb26c06 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a51d09e4b6c8f1803adbdc4d0b3656d7 = $(`&lt;div id=&quot;html_a51d09e4b6c8f1803adbdc4d0b3656d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;154 ST LOUIS AVE &amp; BARNES AVE 5/24/2016 10:38&lt;/div&gt;`)[0];
#                 popup_18253435e8c26c38c9e7ca748bb26c06.setContent(html_a51d09e4b6c8f1803adbdc4d0b3656d7);
#
#
#
#         marker_b4c0ff8e5504d744fc258fd9b2f212cf.bindPopup(popup_18253435e8c26c38c9e7ca748bb26c06)
#         ;
#
#
#
#
#             var marker_b2bc8b8bffff642c98cc4fc93d35644c = L.marker(
#                 [42.9961768984, -76.1402679405],
#                 {}
#             ).addTo(map_c1cd3feafe312d8a3bbf505e6b569033);
#
#
#         var popup_08bd275a0e9ea542955d2c91e0ef0096 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e998a2e862fbf080d7472689f1e30e4d = $(`&lt;div id=&quot;html_e998a2e862fbf080d7472689f1e30e4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;110 COLDBROOK DR &amp; WEYMOUTH R 5/10/2016 9:55&lt;/div&gt;`)[0];
#                 popup_08bd275a0e9ea542955d2c91e0ef0096.setContent(html_e998a2e862fbf080d7472689f1e30e4d);
#
#
#
#         marker_b2bc8b8bffff642c98cc4fc93d35644c.bindPopup(popup_08bd275a0e9ea542955d2c91e0ef0096)
#         ;
#
#
#
#
#             var marker_e20a337742f0a21438775a13d04f7959 = L.marker(
#                 [43.0118856034, -76.1605956476],
#                 {}
#             ).addTo(map_c1cd3feafe312d8a3bbf505e6b569033);
#
#
#         var popup_9a4b7e788c743ca99b20d129bda718f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa4d3b3503b78a1143f9d1c45ac68fe8 = $(`&lt;div id=&quot;html_fa4d3b3503b78a1143f9d1c45ac68fe8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;114 BARNES AVE &amp; PALMER LN 5/24/2016 13:20&lt;/div&gt;`)[0];
#                 popup_9a4b7e788c743ca99b20d129bda718f3.setContent(html_fa4d3b3503b78a1143f9d1c45ac68fe8);
#
#
#
#         marker_e20a337742f0a21438775a13d04f7959.bindPopup(popup_9a4b7e788c743ca99b20d129bda718f3)
#         ;
