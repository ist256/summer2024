# %% [markdown]
# # IST256 Lesson 12
# ## Data Visualizations
#
# - READ: [Fudge: Data Visualizations](DataVisualization.ipynb)
#
# ## Links
#
# - Participation: [https://poll.ist256.com](https://poll.ist256.com)  (Sign in with *netid*@syr.edu and your SU Password.)
# - Class Chat: [https://chat.ist256.com](https://chat.ist256.com)  (Microsoft Teams.)

# %% [markdown]
# # Agenda
#
# - Go over the homework
# - Introduction to Data Visualization
# - Seaborn Basics
# - Folium Basics

# %% [markdown]
# # FEQT (Future Exam Questions Training) 1
#
# Only show part of the data frame where column `b` is an `'x'` ?

# %%
import pandas as pd
x = [ { 'a' :2, 'b' : 'x', 'c' : 10}, 
      { 'a' :4, 'b' : 'y', 'c' : 3},
      { 'a' :1, 'b' : 'x', 'c' : 6} ]
y = pd.DataFrame(x)

# %% [markdown]
# A. `y[ ['b'] == 'x' ]`
# B. `y[ y['b'] == 'x' ]`
# C. `y['b'] == 'x' `
# D. `y[ y['b'] == y['x'] ]`
#
# ## Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
# # FEQT (Future Exam Questions Training) 2
#
# Only show columns `a` and `c` ?

# %%
import pandas as pd
x = [ { 'a' :2, 'b' : 'x', 'c' : 10}, 
      { 'a' :4, 'b' : 'y', 'c' : 3},
      { 'a' :1, 'b' : 'x', 'c' : 6} ]
y = pd.DataFrame(x)
y[ ['a','c'] ]  #column
y[ y['a'] > 1 ] # row

# %% [markdown]
# A. `y[ 'a','c' ]`
# B. `y[ 'ac' ]`
# C. `y[ ['a'],['c'] ] `
# D. `y[ ['a','c'] ]`
#
# ## Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
# # FEQT (Future Exam Questions Training) 3
#
# What is the output of the following code:

# %%
import pandas as pd
x = [ { 'a' :2, 'b' : 'x', 'c' : 10}, 
      { 'a' :4, 'b' : 'y', 'c' : 3},
      { 'a' :1, 'b' : 'x', 'c' : 6} ]
y = pd.DataFrame(x)
for i, z in y.iterrows():
    if z['a']>2:
        print(z['c'])

# %% [markdown]
# A. `10`
# B. `3`
# C. `6`
# D. `4`
#
# ## Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
# # FEQT (Future Exam Questions Training) 4
#
# Which code will output the 2nd row in this data frame?

# %%
import pandas as pd
x = [ { 'a' : {'b' : 'x', 'name' : 'mike'} , 'c' : 10}, 
      { 'a' : {'b' : 'y'}, 'c' : 3},
      { 'a' : {'b' : 'x'}, 'c' : 6} ]
y = pd.json_normalize(x)
y

# %% [markdown]
# A. `y.iloc[1:2]`
# B. `y.iloc[0:2]`
# C. `y[ y['a'] =='y'] `
# D. `y[ y['a:b'] =='y']`
#
# ## Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
# # Connect Activity
#
# **Question:** What is the purpose of a data visualization?
# ![image.png](attachment:image.png)
#
#
# A. `Find relationships in data`
# B. `Find patterns in data`
# C. `Discover meaning in data`
# D. `All of the above`
#
#
# ### Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
# # Data Visualization?
#
# - The study of visual representations of data to reinforce human cognition. “Help people understand the structure, relationships  meaning in data.”
# - **Techniques:** Charts, Graphs, Maps

# %% [markdown]
# ## Anatomy of A Visualization
#
# ![Anatomy![download.png](attachment:c126aaf5-4320-46e2-b887-e5b313a51257.png)](data:image/png;base64,...)

# %% [markdown]
# ## Visualization Heuristics
#
# - A **dimension** goes on the X-Axis. This is some category or time-oriented value such as product type or order date.
# - A **measure** goes on the Y-Axis such as order amount or product quantity
# - Another dimension can be added to the **legend** where we plot the same measure across another group of values. Example: total orders by customer and product type.

# %% [markdown]
# ## Kinds of Visualizations
#
# - **barplot** - categorical data where there is not relationship between the categories.
# - **lineplot** - for time oriented values or other values where there is a seqential relationship.
# - **scatterplot** - for comparison of two measures
# - **histogram** - for counting the frequency of values, placing them into buckets or ranges.

# %% [markdown]
# ## What's wrong with this plot?
#
# ![image.png](attachment:666d4e73-ed13-470b-8bc0-894ab4e2b375.png)

# %% [markdown]
# ## Check Yourself: Plotting Concepts
#
# You would like to plot total number of daily visitors for 5 different websites.
#
# What is the most appropriate visual?
#
#     A. line plot
#     B. bar plot
#     C. scatter plot
#     D. histogram
#
# ### Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
# ## Check Yourself: Plotting Concepts
#
# You would like to visually compare the the miles per gallon of a car to its weight.
#
# What is the most appropriate visual?
#
#     A. line plot
#     B. bar plot
#     C. scatter plot
#     D. histogram
#
# ### Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
# # Seaborn
#
# Seaborn is a Python data visualization library.
#
# - Powerful
# - Simple to use
# - Dataframe friendly
# - Can accomplish significant things with a single line of code
# - Docs, Examples: https://seaborn.pydata.org/

# %% [markdown]
# # Watch Me Code 1!
#
# ### Seaborn data exploration
#
# - explore: https://raw.githubusercontent.com/mafudge/datasets/master/exam-scores/exam-scores.csv
# - `barplot()`, `lineplot()`, `scatterplot()`, `lmplot()`

# %% [markdown]
# ## Check Yourself: Seaborn
#
# To create a scatter with a best fit/regression we use:
#
# What is the most appropriate visual?
#
#     A. lmplot()
#     B. scatterplot()
#     C. regplot()
#     D. histplot()
#
# ### Vote Now: [https://poll.ist256.com](https://poll.ist256.com)

# %% [markdown]
# # Watch Me Code 2!
#
# ### Folium basics
# - Maps, Map
# - Pin Markers
# - https://raw.githubusercontent.com/mafudge/datasets/master/clickstream/ip_lookup.csv
# - Loading from a dataframe

# %% [markdown]
# # End-To-End Example:
#
# ### Potholes on a map
#
# - Let's make a simple map where we plot poholes in the City of Syracuse
# - https://cityofsyracuse.github.io/RoadsChallenge

# %% [markdown]
# # Conclusion Activity: Exit Ticket
#
# To plot time-oriented data such as yearly subscriptions use
#
#     A. histplot()
#     B. lineplot()
#     C. barplot()
#     D. lmplot()
#
#
# ### Vote Now: [https://poll.ist256.com](https://poll.ist256.com)
